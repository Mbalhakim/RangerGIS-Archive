# %%
import pytesseract
from PIL import Image

# %%
img_file = "data/page_01.png"
no_noise = "temp/no_noise.jpg"
inverted_img = "temp/inverted.jpg"

# %%
img = Image.open(no_noise)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=635x901>

# %%
ocr_result = pytesseract.image_to_string(img)

# %%
print (ocr_result)
# Out:
# Pracadvies ten bchoove van do Ruilyerkave2s
#
# smugntan Jat 204 1966 p \W ++ ral
#
# Topografische kasrton 1B. M1 D- 61 B- 416,
#
# Inle}dine
#
# In deze retlvorkaveling, die do gohole genconte alten Yeslaat, kenen varschilzend
# xedieden voor, die op grea yen hi soorten-rikdor on goorten-sanonstelling in dit
# pracaadrles ain opgenonen, Je vale Kleine leofhout boojes center, dic karastoriatic
# Bim voor dit gobted zijn niet cpgenonan. Deze bosjes zijn goede vefusia voor Kleine
# aoogdieren en veroorznken ook da rote vogatrJkdor van dit landscher.
#
# Do op de kaart oranje gokloarde qebledon 2m natuurterrainen’ de groes gearescrde
# torroinen ain bosrebiedon, die tovens veorzonan op da'L'jet van reldingsgebieden
#
# Do ovorigo bescablaten batreffan de raeds eorder gensende Kleine loofhouthos jos
#
# of da groters complexen zonder duidelke natuurrotonschaspeliko wearte.
#
# 1, Hat Goon is gnlegen in hot NoordMostelitk gedeclte van de geneonto.
#
# Het 1s con robled van hoot~ en wetlardjes ongeven door houteallen.
# Wan boleng is bier ock + hat ontbreken van boerderiton, Tevens Lingen nog enkelo
# drockbos jes, waarin cnderstaande planten xorden gevon2ont
#
# a, boonlaset Almas glutinosa, Eavula verracese en Bapabescens, Frangule alas,
# Selix specs, Quercus rebar en Sorbus aeuparie.
#
# Bs stmatiaart Yiburnin cpulus, Contnegus, Ribes sylvectro, Rubus spee, on fubox
#
# Hmb@ase: Carex rerota, Annelice sylvestris, vr veel Veloriana dioica,
# Cireiue palustre, Petentilta erceta, Agrostis stolenifora,
# Iyeopus ourosams on Cliractun deniraides,
#
# De hoctlandan sje plaacselik: wear ‘ratdenrk, eangetro’Cen wordont
#
# Iychnis Pos-cuenli (vol) Carex nigra
# Ranunculus acris (vec) hirta
# Runex sectoza (vacl} Lotus uliginoses
# Cynosurus aristatus Galiue palactra
# Myosoton squatioun Stellaria palustre
# Cardanire pratense (vec!) Galiue, wld inosun
# Veronies sorprilifolia Junees offusus
#
# Bloockeris palustris Mlopeaurns gemiouletas
# Glycorurta fudtens Myosotis palustris
# Fostuce rubra Sagine procunbens
# Antoxantan :doratun Carex rostreta an Carex psoutecorus
#
# Faoiravan Ranurculus aquatilis sep voltatas en plaataclii ‘iottonia palustris,
# ovardgens Nenthe aquatica, 2quisetur Muviatile on douisetun palustre.
#
# De howtyellabies bactean tl.uit Inas glatinesa, Salix avrita, quorcus rotur
# fon Sorbus aucucaria an hothan wen endorgroul van O,a, Peucadanum palustre, Si
# eroctun on Solanun dvlesmare,
#
# Longs do weg stordon ova. nez eangotroffen : Filapondula wWinaria, Bupatorina
# cannabinus, Valoriana offieinalis on Broms mollis.
#
# 2
#
# AAbCALCEYY)
