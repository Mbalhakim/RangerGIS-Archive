# %%
import pytesseract
from PIL import Image

# %%
img_file = "data/page_01.png"
no_noise = "temp/no_noise.jpg"
inverted_img = "temp/inverted.jpg"

# %%
img = Image.open(inverted_img)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=635x901>

# %%
ocr_result = pytesseract.image_to_string(img)

# %%
print (ocr_result)
# Out:
# *
#
# Pracadvies ten behoove van do Ruilverkaveling Aalton 1966
#
# Gorwente: Aalten
#
# Datum inventarisatie: wet 1966 PwHda
# Tovosrafischo kaarton: 41B- 41D 4i BMG.
# Inleiging
#
# In doze rutlverkaveling, dic de gehole gonconte Alten beslaat, konen yverschillend
# gebeden voor, die op grond van hun scorten-rijcdon en soorten-senonstelling in dit
# ‘prae-advies zn opgenonen, De vole Kleine loofhout bosjes ochter, dic karaktoristic
# zijn voor ait gobied ain niet opgenonon. Deze bosjes zi goede refugia voor Kleine
# soogdieren on voroorzaken ook de grote vogelrijkdon van dit landschap.
#
# Do op do kaart oranje gekleurde gobieden 2ijn natuurterreinen: de groen gearceorde
# torreinen zijn bosgebieden, dio tevens voorkonon op de“lijet van moldingsgobieden*
# Do overige bosgebioden botreffen de reeds center gencome Kleine loofhoutbosjos
#
# of do grotere complexen zonder duidelifce natuurvotensohappoliike waardo.
#
# ...
